# %%
import pandas as pd

# Load dataset
df = pd.read_csv("tickets.csv")

print(df.head())
# Out:
#                                 ticket_text         category priority
# 0  My internet is not working since morning  Technical Issue     High
# 1   I was charged twice for my subscription          Billing     High
# 2               How do I reset my password?          Account   Medium
# 3            Please update my email address          Account      Low
# 4     The app keeps crashing when I open it  Technical Issue     High

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Convert text into numerical features
vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(df["ticket_text"])

print(X.shape)
# Out:
# (15, 70)

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df["ticket_text"])

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# Use full dataset
y = df["category"]

model = MultinomialNB()
model.fit(X, y)

# Predict on same dataset (just to check learning)
y_pred = model.predict(X)

accuracy = accuracy_score(y, y_pred)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0

# %%
from sklearn.metrics import confusion_matrix, classification_report

print("Confusion Matrix:")
print(confusion_matrix(y, y_pred))

print("\nClassification Report:")
print(classification_report(y, y_pred))
# Out:
# Confusion Matrix:
# [[4 0 0 0]
#  [0 4 0 0]
#  [0 0 3 0]
#  [0 0 0 4]]
#
# Classification Report:
#                  precision    recall  f1-score   support
#
#         Account       1.00      1.00      1.00         4
#         Billing       1.00      1.00      1.00         4
#   General Query       1.00      1.00      1.00         3
# Technical Issue       1.00      1.00      1.00         4
#
#        accuracy                           1.00        15
#       macro avg       1.00      1.00      1.00        15
#    weighted avg       1.00      1.00      1.00        15

# %%
new_ticket = ["My payment was deducted twice"]

new_ticket_vector = vectorizer.transform(new_ticket)

prediction = model.predict(new_ticket_vector)

print("Predicted Category:", prediction[0])
# Out:
# Predicted Category: Billing

# %%
# Train model for priority
y_priority = df["priority"]

priority_model = MultinomialNB()
priority_model.fit(X, y_priority)

priority_pred = priority_model.predict(X)

priority_accuracy = accuracy_score(y_priority, priority_pred)

print("Priority Model Accuracy:", priority_accuracy)
# Out:
# Priority Model Accuracy: 0.9333333333333333
